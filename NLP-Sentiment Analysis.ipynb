# %%
from textblob import TextBlob
f1=TextBlob("As you know that my salary of February month has not been credited till now, so I am eagerly want to know the exact timing when I will get my salary of mentioned month because I don’t get any information about this matter from your end.For me it is very tough condition to handle this situation because in my family I am only working person, so if I don’t get salary till now, I can’t afford to continue my daily expenditure.From last 5 months my salary had been credited after 10th day of each month. But in this month today is after 15th, till now I don’t get it, so it is very horrible situation for me to handle all things. For that reason my willing of work decreases day by day.Kindly please inform me about this matter as soon as possible.")
f2=TextBlob("Subarata is very bad guy")
print(f1.sentences)
print("*****************************************************")
print(f1.sentiment)
print(f2.sentiment)
print("*****************************************************")
for words in f1.sentences[0].words:  
 print (words)
print("*****************************************************")
for np in f1.noun_phrases:
 print (np)
print("*****************************************************")
for ngram in f1.ngrams(2):
 print(ngram)
# Out:
# [Sentence("As you know that my salary of February month has not been credited till now, so I am eagerly want to know the exact timing when I will get my salary of mentioned month because I don’t get any information about this matter from your end.For me it is very tough condition to handle this situation because in my family I am only working person, so if I don’t get salary till now, I can’t afford to continue my daily expenditure.From last 5 months my salary had been credited after 10th day of each month."), Sentence("But in this month today is after 15th, till now I don’t get it, so it is very horrible situation for me to handle all things."), Sentence("For that reason my willing of work decreases day by day.Kindly please inform me about this matter as soon as possible.")]
# *****************************************************
# Sentiment(polarity=-0.12569444444444444, subjectivity=0.6333333333333333)
# Sentiment(polarity=-0.9099999999999998, subjectivity=0.8666666666666667)
# ...
